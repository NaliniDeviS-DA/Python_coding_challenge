# %% [markdown]
# #Day 43 – While Loop, else, break, continue

# %%
# Project Title: Shopping Cart System
# Scenario:
# You are creating a simple billing system where customers can enter the prices of items they want to purchase.
# The program should keep accepting prices until the user decides to stop, then apply appropriate discounts before generating the final bill.

# Tasks:
# Continuously accept item prices using a while loop.
# Stop taking input when the user enters 0 (sentinel value).
# Keep track of the total number of items and the subtotal amount.
# Ensure no negative prices are allowed (ask again without counting as an item).
# Apply discounts based on the subtotal:
# 20% for totals ≥ 1000
# 10% for totals ≥ 500
# 5% for totals ≥ 200
# 0% for totals < 200
# Display a clear bill summary including subtotal, discount amount, and final total.

sub_total = 0
item_list = []

while True:

  n=int(input("Enter number 0 to stop, enter any other number to continue: "))

  if n < 0:
    print("\nEnter number greater than 0 !!!")
  elif n == 0:
    break
  else:
    item = input("\nEnter Item: ")
    price = int(input("price: "))

    item_list.append(item)
    sub_total = sub_total + price

if sub_total >= 1000:
  Discount = (sub_total * 20) / 100
  print("Discount: ",Discount)
elif 500 <= sub_total <= 1000:
  Discount = (sub_total * 10) / 100
  print("Discount: ",Discount)
elif 200 <= sub_total <= 500:
  Discount = (sub_total * 5) / 100
  print("Discount: ",Discount)
else:
  Discount = 0
  print("Discount: ",Discount)

final_amount = sub_total - Discount
item_count = len(item_list)
print("\nItem List: ",item_list)
print("\nItem count: ",item_count )
print("Total Price: ",sub_total)
print("Discount: ",Discount )
print("Final total amount: ",final_amount )
# Out:
# Enter number 0 to stop, enter any other number to continue: 1
#
# Enter Item: Pen
# price: 600
# Enter number 0 to stop, enter any other number to continue: 2
#
# Enter Item: TV
# price: 5000
# Enter number 0 to stop, enter any other number to continue: 5
#
# Enter Item: Mobile
# price: 5000
# Enter number 0 to stop, enter any other number to continue: 7
#
# Enter Item: Mouse
# price: 600
# Enter number 0 to stop, enter any other number to continue: 0
# Discount:  2240.0
#
# Item List:  ['Pen', 'TV', 'Mobile', 'Mouse']
#
# Item count:  4
# Total Price:  11200
# Discount:  2240.0
# Final total amount:  8960.0
