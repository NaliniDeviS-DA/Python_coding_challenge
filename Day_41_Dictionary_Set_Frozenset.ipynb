# %% [markdown]
# #Day 41 – Dictionary, Set, Frozenset

# %%
# Project Title: Student Grades & Hobbies Tracker
# Scenario:
#  A student activity coordinator is collecting information about student grades and hobbies. They want to ensure grades are updated properly and hobby lists are stored efficiently.

# %%
#Create a dictionary with student names as keys and their grades as values.

std_dict={'Anu':'A', 'Babu':'C', 'Divya':'D','Priya':'A','Suresh':'C'}

# Allow the user to add or update grades for at least 3 students.
std_dict['Babu']='D'
std_dict['Zara']='D'
std_dict['Priya']='A'
print(std_dict)

# Create a set of hobbies and allow the user to input at least 3 hobbies.
# Existing hobbies
Hobbies = {'Swimming', 'Listening to Music', 'Dancing', 'Swimming'}
print("\nExisting Hobbies:", Hobbies)

user_Hobbies = input("Enter at least 3 hobbies (separated by comma): ")
new_hobbies = [hobby.strip() for hobby in user_Hobbies.split(",")]

print(new_hobbies)
Hobbies.update(new_hobbies)

print("\nUpdated Hobbies:", Hobbies)

# Convert the set of hobbies into a frozenset and display it.
F_set=frozenset(Hobbies)
print("\nFrozen Set: ",F_set)
# Out:
# {'Anu': 'A', 'Babu': 'D', 'Divya': 'D', 'Priya': 'A', 'Suresh': 'C', 'Zara': 'D'}
#
# Existing Hobbies: {'Listening to Music', 'Dancing', 'Swimming'}
# Enter at least 3 hobbies (separated by comma): Reading, Painting, Singing
# ['Reading', 'Painting', 'Singing']
#
# Updated Hobbies: {'Reading', 'Painting', 'Singing', 'Listening to Music', 'Dancing', 'Swimming'}
#
# Frozen Set:  frozenset({'Reading', 'Painting', 'Singing', 'Listening to Music', 'Dancing', 'Swimming'})
